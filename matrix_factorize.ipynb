# %% [markdown]
# # Recommendation using matrix factorization

# %% [markdown]
# **Note : Due to the RAM size of the computer(Using M2 MAC BOOK PRO with 16GB of RAM), only transactions from 1000 customers was chosen**
#
# Customers were chosen from the top 3000 total transaction count customers

# %% [markdown]
# ## Import modules

# %%
import random

import numpy as np
import pandas as pd
from scipy.sparse.linalg import svds

# %% [markdown]
# ## Load dataset

# %%
articles = pd.read_csv("datasets/articles.csv")
transaction = pd.read_csv("datasets/transactions_train.csv")
customer = pd.read_csv("datasets/customers.csv")

# %% [markdown]
# ## Choose 1000 customers and filter only transactions from those customers

# %%
customer1000 = (
    transaction["customer_id"]
    .value_counts()
    .head(3000)
    .sample(1000, random_state=1234)
    .index
)

# %%
transaction_filtered = transaction[transaction["customer_id"].isin(customer1000)]

# %%
len(transaction_filtered)
# Out:
# 418739

# %% [markdown]
# ## Create a pivot table of customer_id X article_id

# %% [markdown]
# Before creating the pivot table, I've created a rating table of customer to the article by using how many items the customer bought the item from the whole transaction data
#
# This is due to the fact that there is no significant rating information in the datasets and to compensate this, used the fact that if the customer bought the same item many times this could mean that the customer liked the item
#
# And squared the items count each user bought

# %%
customer_article_df = (
    transaction_filtered[["customer_id", "article_id"]]
    .value_counts()
    .to_frame()
    .reset_index()
    .pivot_table(
        index="customer_id", columns="article_id", values="count", fill_value=0.0
    )
)

# %%
customer_article_df
# Out:
# article_id                                          108775015  108775044
# customer_id
# 00357b192b81fc83261a45be87f5f3d59112db7d117513c...          0          0  \
# 00754012108569f9c99871720111a2b50aa7b6ebebe2a41...          0          0
# 0077922bc342aca5f3ad0a67198ce22779eeb89f9861b96...          0          0
# 0083ee250b3845008465de0e938d0ed2ae4f5bfde8b56ee...          0          0
# 00e59bc10e162c83758a8ece0d6536d96fe2c7afdae9d5f...          2          0
# ...                                                       ...        ...
# ff639548ca0e8864613d7be6f397125a9f7aa5913165f8e...          0          0
# ff7313f354e805f6ace690ddaa753d302341dd810a4a59c...          0          0
# ffc247b933f175b37fccbb4f71c0479d6625e703b36f637...          0          0
# ffe6376eb6b854d842e5a7714ea758de127f086a60d67d5...          0          0
# fff2282977442e327b45d8c89afde25617d00124d0f9998...          0          0
#
# article_id                                          108775051  110065001
# customer_id
# 00357b192b81fc83261a45be87f5f3d59112db7d117513c...          0          0  \
# 00754012108569f9c99871720111a2b50aa7b6ebebe2a41...          0          0
# 0077922bc342aca5f3ad0a67198ce22779eeb89f9861b96...          0          0
# 0083ee250b3845008465de0e938d0ed2ae4f5bfde8b56ee...          0          0
# 00e59bc10e162c83758a8ece0d6536d96fe2c7afdae9d5f...          0          0
# ...                                                       ...        ...
# ff639548ca0e8864613d7be6f397125a9f7aa5913165f8e...          0          0
# ff7313f354e805f6ace690ddaa753d302341dd810a4a59c...          0          0
# ffc247b933f175b37fccbb4f71c0479d6625e703b36f637...          0          0
# ffe6376eb6b854d842e5a7714ea758de127f086a60d67d5...          0          0
# fff2282977442e327b45d8c89afde25617d00124d0f9998...          0          0
#
# article_id                                          110065002  110065011
# customer_id
# 00357b192b81fc83261a45be87f5f3d59112db7d117513c...          0          0  \
# 00754012108569f9c99871720111a2b50aa7b6ebebe2a41...          0          0
# 0077922bc342aca5f3ad0a67198ce22779eeb89f9861b96...          0          0
# 0083ee250b3845008465de0e938d0ed2ae4f5bfde8b56ee...          0          0
# 00e59bc10e162c83758a8ece0d6536d96fe2c7afdae9d5f...          0          0
# ...                                                       ...        ...
# ff639548ca0e8864613d7be6f397125a9f7aa5913165f8e...          0          0
# ff7313f354e805f6ace690ddaa753d302341dd810a4a59c...          0          0
# ffc247b933f175b37fccbb4f71c0479d6625e703b36f637...          0          0
# ffe6376eb6b854d842e5a7714ea758de127f086a60d67d5...          0          0
# fff2282977442e327b45d8c89afde25617d00124d0f9998...          0          0
#
# article_id                                          111565001  111586001
# customer_id
# 00357b192b81fc83261a45be87f5f3d59112db7d117513c...          0          0  \
# 00754012108569f9c99871720111a2b50aa7b6ebebe2a41...          0          0
# 0077922bc342aca5f3ad0a67198ce22779eeb89f9861b96...          0          0
# 0083ee250b3845008465de0e938d0ed2ae4f5bfde8b56ee...          0          0
# 00e59bc10e162c83758a8ece0d6536d96fe2c7afdae9d5f...          0          0
# ...                                                       ...        ...
# ff639548ca0e8864613d7be6f397125a9f7aa5913165f8e...          0          0
# ff7313f354e805f6ace690ddaa753d302341dd810a4a59c...          0          0
# ffc247b933f175b37fccbb4f71c0479d6625e703b36f637...          0          0
# ffe6376eb6b854d842e5a7714ea758de127f086a60d67d5...          0          0
# fff2282977442e327b45d8c89afde25617d00124d0f9998...          0          0
#
# article_id                                          111593001  111609001  ...
# customer_id                                                               ...
# 00357b192b81fc83261a45be87f5f3d59112db7d117513c...          0          0  ...  \
# 00754012108569f9c99871720111a2b50aa7b6ebebe2a41...          0          0  ...
# 0077922bc342aca5f3ad0a67198ce22779eeb89f9861b96...          0          0  ...
# 0083ee250b3845008465de0e938d0ed2ae4f5bfde8b56ee...          0          0  ...
# 00e59bc10e162c83758a8ece0d6536d96fe2c7afdae9d5f...          0          0  ...
# ...                                                       ...        ...  ...
# ff639548ca0e8864613d7be6f397125a9f7aa5913165f8e...          0          0  ...
# ff7313f354e805f6ace690ddaa753d302341dd810a4a59c...          0          0  ...
# ffc247b933f175b37fccbb4f71c0479d6625e703b36f637...          0          0  ...
# ffe6376eb6b854d842e5a7714ea758de127f086a60d67d5...          0          0  ...
# fff2282977442e327b45d8c89afde25617d00124d0f9998...          0          0  ...
#
# article_id                                          946827001  946827002
# customer_id
# 00357b192b81fc83261a45be87f5f3d59112db7d117513c...          0          0  \
# 00754012108569f9c99871720111a2b50aa7b6ebebe2a41...          0          0
# 0077922bc342aca5f3ad0a67198ce22779eeb89f9861b96...          0          0
# 0083ee250b3845008465de0e938d0ed2ae4f5bfde8b56ee...          0          0
# 00e59bc10e162c83758a8ece0d6536d96fe2c7afdae9d5f...          0          0
# ...                                                       ...        ...
# ff639548ca0e8864613d7be6f397125a9f7aa5913165f8e...          0          0
# ff7313f354e805f6ace690ddaa753d302341dd810a4a59c...          0          0
# ffc247b933f175b37fccbb4f71c0479d6625e703b36f637...          0          0
# ffe6376eb6b854d842e5a7714ea758de127f086a60d67d5...          0          0
# fff2282977442e327b45d8c89afde25617d00124d0f9998...          0          0
#
# article_id                                          947060001  947168001
# customer_id
# 00357b192b81fc83261a45be87f5f3d59112db7d117513c...          0          0  \
# 00754012108569f9c99871720111a2b50aa7b6ebebe2a41...          0          0
# 0077922bc342aca5f3ad0a67198ce22779eeb89f9861b96...          0          0
# 0083ee250b3845008465de0e938d0ed2ae4f5bfde8b56ee...          0          0
# 00e59bc10e162c83758a8ece0d6536d96fe2c7afdae9d5f...          0          0
# ...                                                       ...        ...
# ff639548ca0e8864613d7be6f397125a9f7aa5913165f8e...          0          0
# ff7313f354e805f6ace690ddaa753d302341dd810a4a59c...          0          0
# ffc247b933f175b37fccbb4f71c0479d6625e703b36f637...          0          0
# ffe6376eb6b854d842e5a7714ea758de127f086a60d67d5...          0          0
# fff2282977442e327b45d8c89afde25617d00124d0f9998...          0          0
#
# article_id                                          947509001  949198001
# customer_id
# 00357b192b81fc83261a45be87f5f3d59112db7d117513c...          0          0  \
# 00754012108569f9c99871720111a2b50aa7b6ebebe2a41...          0          0
# 0077922bc342aca5f3ad0a67198ce22779eeb89f9861b96...          0          0
# 0083ee250b3845008465de0e938d0ed2ae4f5bfde8b56ee...          0          0
# 00e59bc10e162c83758a8ece0d6536d96fe2c7afdae9d5f...          0          0
# ...                                                       ...        ...
# ff639548ca0e8864613d7be6f397125a9f7aa5913165f8e...          0          0
# ff7313f354e805f6ace690ddaa753d302341dd810a4a59c...          0          0
# ffc247b933f175b37fccbb4f71c0479d6625e703b36f637...          0          0
# ffe6376eb6b854d842e5a7714ea758de127f086a60d67d5...          0          0
# fff2282977442e327b45d8c89afde25617d00124d0f9998...          0          0
#
# article_id                                          949551001  949551002
# customer_id
# 00357b192b81fc83261a45be87f5f3d59112db7d117513c...          0          0  \
# 00754012108569f9c99871720111a2b50aa7b6ebebe2a41...          0          1
# 0077922bc342aca5f3ad0a67198ce22779eeb89f9861b96...          0          0
# 0083ee250b3845008465de0e938d0ed2ae4f5bfde8b56ee...          0          0
# 00e59bc10e162c83758a8ece0d6536d96fe2c7afdae9d5f...          0          0
# ...                                                       ...        ...
# ff639548ca0e8864613d7be6f397125a9f7aa5913165f8e...          0          0
# ff7313f354e805f6ace690ddaa753d302341dd810a4a59c...          0          0
# ffc247b933f175b37fccbb4f71c0479d6625e703b36f637...          0          0
# ffe6376eb6b854d842e5a7714ea758de127f086a60d67d5...          0          0
# fff2282977442e327b45d8c89afde25617d00124d0f9998...          0          0
#
# article_id                                          953763001  956217002
# customer_id
# 00357b192b81fc83261a45be87f5f3d59112db7d117513c...          0          0
# 00754012108569f9c99871720111a2b50aa7b6ebebe2a41...          0          0
# 0077922bc342aca5f3ad0a67198ce22779eeb89f9861b96...          0          0
# 0083ee250b3845008465de0e938d0ed2ae4f5bfde8b56ee...          0          0
# 00e59bc10e162c83758a8ece0d6536d96fe2c7afdae9d5f...          0          0
# ...                                                       ...        ...
# ff639548ca0e8864613d7be6f397125a9f7aa5913165f8e...          0          0
# ff7313f354e805f6ace690ddaa753d302341dd810a4a59c...          0          0
# ffc247b933f175b37fccbb4f71c0479d6625e703b36f637...          0          0
# ffe6376eb6b854d842e5a7714ea758de127f086a60d67d5...          0          0
# fff2282977442e327b45d8c89afde25617d00124d0f9998...          0          0
#
# [1000 rows x 56415 columns]

# %%
customer_article_mat = customer_article_df.to_numpy()

# %%
customer_article_mat.shape
# Out:
# (1000, 56415)

# %% [markdown]
# ## Do a Truncated Singular Value Decomposition

# %%
mean_per_user = customer_article_mat.mean(axis=1).reshape(-1, 1)
mat_del_mean = customer_article_mat - mean_per_user

U, sigma, Vt = svds(mat_del_mean, k=100)
sigma = np.diag(sigma)

# %%
U.shape
# Out:
# (1000, 100)

# %%
sigma.shape
# Out:
# (100, 100)

# %%
Vt.shape
# Out:
# (100, 56415)

# %% [markdown]
# ## Predict the User x Item transaction

# %%
predicted_user_trans_mat = U @ sigma @ Vt + mean_per_user

# %%
predicted_user_trans_mat.shape
# Out:
# (1000, 56415)

# %%
predicted_user_trans_df = pd.DataFrame(
    predicted_user_trans_mat,
    index=customer_article_df.index,
    columns=customer_article_df.columns,
)

# %% [markdown]
# ## Create a simple recommendation function
#
# Used the prediction dataframe from above
#
# This function recommends items that the user have not bought, but only users from the filtered 1000 users can only be recommended and only the items these users bought will only in the recommendation list

# %%
def print_item_info(item_no, detail_output=False):
    columns_to_print = [
        "prod_name",
        "product_type_name",
        "graphical_appearance_name",
        "colour_group_name",
        "section_name",
        "detail_desc",
    ]

    item_info = articles.loc[
        articles["article_id"].eq(item_no), columns_to_print
    ].squeeze()

    if detail_output:
        print(
            f'- "{item_info["prod_name"]}" which is a "{item_info["product_type_name"]}" with a color pattern of "{item_info["graphical_appearance_name"]} {item_info["colour_group_name"]}", it is a "{item_info["section_name"]}" and a detail description is "{item_info["detail_desc"]}"'
        )
    else:
        print(
            f'- {item_info["prod_name"]} : {item_info["graphical_appearance_name"]} {item_info["colour_group_name"]} {item_info["product_type_name"]}'
        )


def recommend_item_to_user(customer_id, detail_output=False):
    assert (
        customer_id in predicted_user_trans_df.index
    ), "Customer id not in prediction DataFrame."

    bought_items = transaction[transaction["customer_id"].eq(customer_id)][
        "article_id"
    ].unique()

    print("<Bought products info>")
    for item in bought_items:
        print_item_info(item, detail_output)

    predicted = predicted_user_trans_df.loc[customer_id]
    # filter out items which the user have not bought
    # order by the larges score and filter top 10
    top10_items = predicted[~predicted.index.isin(bought_items)].sort_values(
        ascending=False
    ).head(10)

    if len(top10_items) == 0:
        print("There is no items to recommend")
        return
    
    print("\n\n<Recommended Items>")
    for item in top10_items.index:
        print_item_info(item, detail_output)

# %%
test = recommend_item_to_user(random.choice(predicted_user_trans_df.index))
# Out:
# <Bought products info>
# - Shaping Skinny R.W. : Denim Grey Trousers
# - Artic : Melange Yellow Sweater
# - Honey : Colour blocking Black Leggings/Tights
# - DORIS CREW : Sequin Black Sweater
# - BASIC HOOD : Melange Light Pink Hoodie
# - DORIS CREW : Embroidery Grey Sweater
# - Eclipse Hood : Colour blocking Dark Blue Hoodie
# - EUCALYPTUS TM 19.99 : Colour blocking Dark Blue Sweater
# - HOLLY : Colour blocking Black Leggings/Tights
# - Perfect hood : Colour blocking Light Pink Sweater
# - HERBAL HOOD TVP : Placement print Light Grey Hoodie
# - HERBAL HOOD TVP : Placement print Dark Blue Hoodie
# - Milk RW slacks : Mixed solid/pattern Black Trousers
# - Greyworm tapered trouser RW : Solid Black Trousers
# - SPEED WANDA cropped ls : Solid White Top
# - Russel hood : Front print Black Sweater
# - SUZY HALF ZIP LOW LOW : Front print Yellow Top
# - GWEN ss tee : Solid Yellow T-shirt
# - Lolly skirt velour : Other structure Dark Blue Skirt
# - LARISSA hood : Solid White Hoodie
# - GWEN ss tee : Solid Dark Blue T-shirt
# - TUXEDO pant : Melange Dark Grey Leggings/Tights
# - SPEED WANDA cropped ls : Solid Light Blue Top
# - HONEY 2-P LEGGINGS : All over pattern Dark Blue Leggings/Tights
# - PEACH solid single tee : Solid White T-shirt
# - SERENA 2p tank : Solid Black Vest top
# - TUXEDO pant : Solid Dark Blue Leggings/Tights
# - DEBBIE top : Stripe White Top
# - HOLMES fancy (1) : Solid Black Trousers
# - Noora : Placement print Light Blue Sweater
# - Noora : Placement print White Sweater
# - LARISSA hood : Other structure Greenish Khaki Hoodie
# - Kompis L/S fancy : Stripe White Sweater
# - Russel hood : Front print Yellow Sweater
# - LARISSA hood : Solid Dark Blue Hoodie
# - GWEN ss tee : Solid Light Blue T-shirt
# - LOLLY SKIRT (1) : Solid Black Skirt
# - Flygare style : Front print Yellow T-shirt
# - Noora : Solid Dark Blue Sweater
# - Noora : Placement print Greenish Khaki Sweater
# - HOLMES fancy (1) : Melange Grey Trousers
# - Saga LS low price : Front print White T-shirt
# - HOLMES sweat trousers : Melange Black Trousers
# - Noora : Melange Grey Sweater
# - TUXEDO pant : Solid Black Leggings/Tights
# - RELAXED SKINNY HANA : Denim Blue Trousers
# - SERENA 2p tank (1) : Melange Grey Vest top
# - PEACH solid single tee : Solid Black T-shirt
# - SKINNY TRASH 89 : Denim Light Blue Trousers
# - SKINNY HW PETRA : Denim Light Blue Trousers
# - SKINNY NELSON PANEL : Denim Light Blue Trousers
# - Skinny trash SPEED : Denim Light Blue Trousers
# - SKINNY HW KIM BF 89 : Denim Dark Blue Trousers
# - HOLMES 2p trousers : Melange Greenish Khaki Trousers
# - Ida Panel Jogger : Solid Black Trousers
# - &DENIM Lou shirtdress : Denim Blue Dress
# - FELIX JOGGER TERRY : Solid Grey Trousers
# - Bradley : Melange Grey Trousers
# - PULL ON JOGGER : Melange Grey Trousers
# - Uno Hood (1) : Colour blocking Black Hoodie
# - Bradley (1) : Solid Dark Pink Trousers
# - Bradley : Melange Dark Grey Trousers
# - Uno Hood (1) : Solid Black Hoodie
# - Ida Panel Jogger : Solid Grey Trousers
# - Uno Hood (1) : Colour blocking Dark Blue Hoodie
# - + Rolls Royce Swimsuite : Solid Dark Blue Swimsuit
# - Kim 2p padded BIG : Melange Grey Bra
# - DIV Nicky long tank top : Solid White Vest top
# - Kivik Linen Popover : Solid White Shirt
# - + Coco Shape Bottom : Solid Dark Green Swimwear bottom
# - + Miami Wire bra : Solid Dark Green Bikini top
# - Kivik Linen Popover : Stripe Light Blue Shirt
# - Make Over Brief : Solid Red Swimwear bottom
# - Timeless Push Up Tie back Bra : Other structure Dark Green Bikini top
# - STORK FANCY : Solid Green T-shirt
# - Dixie tee 9.99 : Placement print White T-shirt
# - Lisa Bodycon dress : Solid Red Dress
# - Olga Tank : Stripe Dark Blue Vest top
# - Waif Wide leg trouser RW : Stripe Dark Blue Trousers
# - Mojito : Stripe Light Blue Blouse
# - Stannis paperbag culotte HW : Chambray Dark Blue Trousers
# - BOUNTY : All over pattern Black Vest top
# - PRICE TEE : All over pattern Black T-shirt
# - Timeless Highwaist : Solid Black Swimwear bottom
# - Olga Tank TVP : Solid Yellow Vest top
# - Dixie tee 9.99 : Placement print Black T-shirt
# - Katsu : All over pattern Off White Dress
# - Sibling HW : Solid Light Blue Shorts
# - Bianca strapless BIG : Solid Light Beige Bra
# - Boy Denim Shorts : Solid Blue Shorts
# - Ozzy Denim Shorts : Solid Dark Blue Shorts
# - Lola RW Denim Shorts : Solid Light Blue Shorts
# - Lola Denim Shorts : Solid Blue Shorts
# - Lola Denim Shorts : Solid Blue Shorts
# - &DENIM jen bermuda shorts : Denim Black Shorts
# - Brit Baby Tee : Solid Pink T-shirt
# - Boy Denim Shorts : Solid Light Blue Shorts
# - Brit Baby Tee : Solid Black T-shirt
# - Jen Bermuda Shorts : Denim Light Blue Shorts
# - Ozzy Denim Shorts : Solid Light Blue Shorts
# - Brit Baby Tee : Stripe White T-shirt
# - BOULEVARD TEE TVP : Placement print Yellow T-shirt
# - BOULEVARD TEE TVP : Placement print White T-shirt
# - Shaping Skinny R.W : Denim Blue Trousers
# - Skinny Ankle R.W Brooklyn : Denim Grey Trousers
# - B Luca Pareo : Placement print Black Sarong
# - Bieber strawhat SPEED : Solid Off White Hat/brim
# - MEMPHIS sweater : Stripe Yellow Sweater
# - Noora : Colour blocking Yellow Sweater
# - Fia 2-p kneehigh BG : Other pattern Black Socks
# - MOMO cropt top : Solid Black Sweater
# - Wilma skirt : Treatment Black Skirt
# - BETH PRICE SWETTIS : Front print Yellow Sweater
# - Harper blouse : All over pattern Black Shirt
# - Tiblisi paperbag slacks : Solid Black Trousers
# - Presley PU skirt : Solid Black Skirt
# - MOMO cropt top : Stripe White Sweater
# - Family hood women : Melange Grey Sweater
# - MOMO cropt top : Solid Yellow Sweater
# - Bonnie : Stripe Black Sweater
# - MOMO cropt top : Solid Red Sweater
# - ED Primo slacks : Solid Black Trousers
# - ED Pluto RW slacks : Solid Black Trousers
# - Family crew women : Solid Yellow Sweater
# - SKINNY PRICE 89 : Denim Grey Trousers
# - JLO LEGGINGS : Treatment Dark Blue Leggings/Tights
# - JLO LEGGINGS : Treatment Dark Grey Leggings/Tights
# - SAGE slim trouser : Colour blocking Black Trousers
# - SAGE slim trouser : Colour blocking Dark Blue Trousers
# - SAGE slim trouser : Colour blocking Black Trousers
# - ED Kalinda trouser : Check Black Trousers
# - &DENIM+ Skinny shaping RW : Denim Dark Blue Trousers
# - Jade Trash HW Skinny Denim TRS : Solid Dark Grey Trousers
# - Jade Denim HW trs : Solid Blue Trousers
# - Jade HW Skinny Denim TRS : Solid Light Blue Trousers
# - Herbal Hood- TVP : Placement print Yellow Hoodie
# - Jade HW Skinny Denim TRS : Solid Light Blue Trousers
# - Jade HW Skinny Denim TRS : Solid Black Trousers
# - &DENIM+ Skinny shaping RW : Denim Black Trousers
# - Virgo Hip belt : Solid Black Belt
# - SKINNY HW KIM : Denim Dark Blue Trousers
# - SKROLLAN tiger (W) : Solid Dark Orange Belt
# - SKINNY BASIC 89 : Denim Blue Trousers
# - SKINNY TRASH 89 : Denim Blue Trousers
# - SKINNY BASIC 89 : Denim Grey Trousers
# - SKINNY SUPER SOFT : Denim Light Blue Trousers
# - SKINNY SUPERBLING BLK : Denim Black Trousers
# - SKINNY FANCY : Denim Light Blue Trousers
# - SKINNY TRASH 89 : Denim Black Trousers
# - SKINNY BASIC 89 : Denim Dark Blue Trousers
