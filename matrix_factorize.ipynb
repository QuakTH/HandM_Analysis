# %% [markdown]
# # Recommendation using matrix factorization

# %% [markdown]
# **Note : Due to the RAM size of the computer(Using M2 MAC BOOK PRO with 16GB of RAM), only transactions from 1000 customers was chosen**
#
# Customers were chosen from the top 3000 total transaction count customers

# %% [markdown]
# ## Import modules

# %%
import random

import numpy as np
import pandas as pd
from scipy.sparse.linalg import svds

# %% [markdown]
# ## Load dataset

# %%
articles = pd.read_csv("datasets/articles.csv")
transaction = pd.read_csv("datasets/transactions_train.csv")
customer = pd.read_csv("datasets/customers.csv")

# %% [markdown]
# ## Choose 1000 customers and filter only transactions from those customers

# %%
customer1000 = (
    transaction["customer_id"]
    .value_counts()
    .head(3000)
    .sample(1000, random_state=1234)
    .index
)

# %%
transaction_filtered = transaction[transaction["customer_id"].isin(customer1000)]

# %%
len(transaction_filtered)
# Out:
# 418739

# %% [markdown]
# ## Create a pivot table of customer_id X article_id

# %% [markdown]
# Before creating the pivot table, I've created a rating table of customer to the article by using how many items the customer bought the item from the whole transaction data
#
# This is due to the fact that there is no significant rating information in the datasets and to compensate this, used the fact that if the customer bought the same item many times this could mean that the customer liked the item
#
# And squared the items count each user bought

# %%
customer_article_df = (
    transaction_filtered[["customer_id", "article_id"]]
    .value_counts()
    .to_frame()
    .reset_index()
    .pivot_table(
        index="customer_id", columns="article_id", values="count", fill_value=0.0
    )
)

# %%
customer_article_df
# Out:
# article_id                                          108775015  108775044
# customer_id
# 00357b192b81fc83261a45be87f5f3d59112db7d117513c...          0          0  \
# 00754012108569f9c99871720111a2b50aa7b6ebebe2a41...          0          0
# 0077922bc342aca5f3ad0a67198ce22779eeb89f9861b96...          0          0
# 0083ee250b3845008465de0e938d0ed2ae4f5bfde8b56ee...          0          0
# 00e59bc10e162c83758a8ece0d6536d96fe2c7afdae9d5f...          2          0
# ...                                                       ...        ...
# ff639548ca0e8864613d7be6f397125a9f7aa5913165f8e...          0          0
# ff7313f354e805f6ace690ddaa753d302341dd810a4a59c...          0          0
# ffc247b933f175b37fccbb4f71c0479d6625e703b36f637...          0          0
# ffe6376eb6b854d842e5a7714ea758de127f086a60d67d5...          0          0
# fff2282977442e327b45d8c89afde25617d00124d0f9998...          0          0
#
# article_id                                          108775051  110065001
# customer_id
# 00357b192b81fc83261a45be87f5f3d59112db7d117513c...          0          0  \
# 00754012108569f9c99871720111a2b50aa7b6ebebe2a41...          0          0
# 0077922bc342aca5f3ad0a67198ce22779eeb89f9861b96...          0          0
# 0083ee250b3845008465de0e938d0ed2ae4f5bfde8b56ee...          0          0
# 00e59bc10e162c83758a8ece0d6536d96fe2c7afdae9d5f...          0          0
# ...                                                       ...        ...
# ff639548ca0e8864613d7be6f397125a9f7aa5913165f8e...          0          0
# ff7313f354e805f6ace690ddaa753d302341dd810a4a59c...          0          0
# ffc247b933f175b37fccbb4f71c0479d6625e703b36f637...          0          0
# ffe6376eb6b854d842e5a7714ea758de127f086a60d67d5...          0          0
# fff2282977442e327b45d8c89afde25617d00124d0f9998...          0          0
#
# article_id                                          110065002  110065011
# customer_id
# 00357b192b81fc83261a45be87f5f3d59112db7d117513c...          0          0  \
# 00754012108569f9c99871720111a2b50aa7b6ebebe2a41...          0          0
# 0077922bc342aca5f3ad0a67198ce22779eeb89f9861b96...          0          0
# 0083ee250b3845008465de0e938d0ed2ae4f5bfde8b56ee...          0          0
# 00e59bc10e162c83758a8ece0d6536d96fe2c7afdae9d5f...          0          0
# ...                                                       ...        ...
# ff639548ca0e8864613d7be6f397125a9f7aa5913165f8e...          0          0
# ff7313f354e805f6ace690ddaa753d302341dd810a4a59c...          0          0
# ffc247b933f175b37fccbb4f71c0479d6625e703b36f637...          0          0
# ffe6376eb6b854d842e5a7714ea758de127f086a60d67d5...          0          0
# fff2282977442e327b45d8c89afde25617d00124d0f9998...          0          0
#
# article_id                                          111565001  111586001
# customer_id
# 00357b192b81fc83261a45be87f5f3d59112db7d117513c...          0          0  \
# 00754012108569f9c99871720111a2b50aa7b6ebebe2a41...          0          0
# 0077922bc342aca5f3ad0a67198ce22779eeb89f9861b96...          0          0
# 0083ee250b3845008465de0e938d0ed2ae4f5bfde8b56ee...          0          0
# 00e59bc10e162c83758a8ece0d6536d96fe2c7afdae9d5f...          0          0
# ...                                                       ...        ...
# ff639548ca0e8864613d7be6f397125a9f7aa5913165f8e...          0          0
# ff7313f354e805f6ace690ddaa753d302341dd810a4a59c...          0          0
# ffc247b933f175b37fccbb4f71c0479d6625e703b36f637...          0          0
# ffe6376eb6b854d842e5a7714ea758de127f086a60d67d5...          0          0
# fff2282977442e327b45d8c89afde25617d00124d0f9998...          0          0
#
# article_id                                          111593001  111609001  ...
# customer_id                                                               ...
# 00357b192b81fc83261a45be87f5f3d59112db7d117513c...          0          0  ...  \
# 00754012108569f9c99871720111a2b50aa7b6ebebe2a41...          0          0  ...
# 0077922bc342aca5f3ad0a67198ce22779eeb89f9861b96...          0          0  ...
# 0083ee250b3845008465de0e938d0ed2ae4f5bfde8b56ee...          0          0  ...
# 00e59bc10e162c83758a8ece0d6536d96fe2c7afdae9d5f...          0          0  ...
# ...                                                       ...        ...  ...
# ff639548ca0e8864613d7be6f397125a9f7aa5913165f8e...          0          0  ...
# ff7313f354e805f6ace690ddaa753d302341dd810a4a59c...          0          0  ...
# ffc247b933f175b37fccbb4f71c0479d6625e703b36f637...          0          0  ...
# ffe6376eb6b854d842e5a7714ea758de127f086a60d67d5...          0          0  ...
# fff2282977442e327b45d8c89afde25617d00124d0f9998...          0          0  ...
#
# article_id                                          946827001  946827002
# customer_id
# 00357b192b81fc83261a45be87f5f3d59112db7d117513c...          0          0  \
# 00754012108569f9c99871720111a2b50aa7b6ebebe2a41...          0          0
# 0077922bc342aca5f3ad0a67198ce22779eeb89f9861b96...          0          0
# 0083ee250b3845008465de0e938d0ed2ae4f5bfde8b56ee...          0          0
# 00e59bc10e162c83758a8ece0d6536d96fe2c7afdae9d5f...          0          0
# ...                                                       ...        ...
# ff639548ca0e8864613d7be6f397125a9f7aa5913165f8e...          0          0
# ff7313f354e805f6ace690ddaa753d302341dd810a4a59c...          0          0
# ffc247b933f175b37fccbb4f71c0479d6625e703b36f637...          0          0
# ffe6376eb6b854d842e5a7714ea758de127f086a60d67d5...          0          0
# fff2282977442e327b45d8c89afde25617d00124d0f9998...          0          0
#
# article_id                                          947060001  947168001
# customer_id
# 00357b192b81fc83261a45be87f5f3d59112db7d117513c...          0          0  \
# 00754012108569f9c99871720111a2b50aa7b6ebebe2a41...          0          0
# 0077922bc342aca5f3ad0a67198ce22779eeb89f9861b96...          0          0
# 0083ee250b3845008465de0e938d0ed2ae4f5bfde8b56ee...          0          0
# 00e59bc10e162c83758a8ece0d6536d96fe2c7afdae9d5f...          0          0
# ...                                                       ...        ...
# ff639548ca0e8864613d7be6f397125a9f7aa5913165f8e...          0          0
# ff7313f354e805f6ace690ddaa753d302341dd810a4a59c...          0          0
# ffc247b933f175b37fccbb4f71c0479d6625e703b36f637...          0          0
# ffe6376eb6b854d842e5a7714ea758de127f086a60d67d5...          0          0
# fff2282977442e327b45d8c89afde25617d00124d0f9998...          0          0
#
# article_id                                          947509001  949198001
# customer_id
# 00357b192b81fc83261a45be87f5f3d59112db7d117513c...          0          0  \
# 00754012108569f9c99871720111a2b50aa7b6ebebe2a41...          0          0
# 0077922bc342aca5f3ad0a67198ce22779eeb89f9861b96...          0          0
# 0083ee250b3845008465de0e938d0ed2ae4f5bfde8b56ee...          0          0
# 00e59bc10e162c83758a8ece0d6536d96fe2c7afdae9d5f...          0          0
# ...                                                       ...        ...
# ff639548ca0e8864613d7be6f397125a9f7aa5913165f8e...          0          0
# ff7313f354e805f6ace690ddaa753d302341dd810a4a59c...          0          0
# ffc247b933f175b37fccbb4f71c0479d6625e703b36f637...          0          0
# ffe6376eb6b854d842e5a7714ea758de127f086a60d67d5...          0          0
# fff2282977442e327b45d8c89afde25617d00124d0f9998...          0          0
#
# article_id                                          949551001  949551002
# customer_id
# 00357b192b81fc83261a45be87f5f3d59112db7d117513c...          0          0  \
# 00754012108569f9c99871720111a2b50aa7b6ebebe2a41...          0          1
# 0077922bc342aca5f3ad0a67198ce22779eeb89f9861b96...          0          0
# 0083ee250b3845008465de0e938d0ed2ae4f5bfde8b56ee...          0          0
# 00e59bc10e162c83758a8ece0d6536d96fe2c7afdae9d5f...          0          0
# ...                                                       ...        ...
# ff639548ca0e8864613d7be6f397125a9f7aa5913165f8e...          0          0
# ff7313f354e805f6ace690ddaa753d302341dd810a4a59c...          0          0
# ffc247b933f175b37fccbb4f71c0479d6625e703b36f637...          0          0
# ffe6376eb6b854d842e5a7714ea758de127f086a60d67d5...          0          0
# fff2282977442e327b45d8c89afde25617d00124d0f9998...          0          0
#
# article_id                                          953763001  956217002
# customer_id
# 00357b192b81fc83261a45be87f5f3d59112db7d117513c...          0          0
# 00754012108569f9c99871720111a2b50aa7b6ebebe2a41...          0          0
# 0077922bc342aca5f3ad0a67198ce22779eeb89f9861b96...          0          0
# 0083ee250b3845008465de0e938d0ed2ae4f5bfde8b56ee...          0          0
# 00e59bc10e162c83758a8ece0d6536d96fe2c7afdae9d5f...          0          0
# ...                                                       ...        ...
# ff639548ca0e8864613d7be6f397125a9f7aa5913165f8e...          0          0
# ff7313f354e805f6ace690ddaa753d302341dd810a4a59c...          0          0
# ffc247b933f175b37fccbb4f71c0479d6625e703b36f637...          0          0
# ffe6376eb6b854d842e5a7714ea758de127f086a60d67d5...          0          0
# fff2282977442e327b45d8c89afde25617d00124d0f9998...          0          0
#
# [1000 rows x 56415 columns]

# %%
customer_article_mat = customer_article_df.to_numpy()

# %%
customer_article_mat.shape
# Out:
# (1000, 56415)

# %% [markdown]
# ## Do a Truncated Singular Value Decomposion

# %%
mean_per_user = customer_article_mat.mean(axis=1).reshape(-1, 1)
mat_del_mean = customer_article_mat - mean_per_user

U, sigma, Vt = svds(mat_del_mean, k=100)
sigma = np.diag(sigma)

# %%
U.shape
# Out:
# (1000, 100)

# %%
sigma.shape
# Out:
# (100, 100)

# %%
Vt.shape
# Out:
# (100, 56415)

# %% [markdown]
# ## Predict the User x Item transaction

# %%
predicted_user_trans_mat = U @ sigma @ Vt + mean_per_user

# %%
predicted_user_trans_mat.shape
# Out:
# (1000, 56415)

# %%
predicted_user_trans_df = pd.DataFrame(
    predicted_user_trans_mat,
    index=customer_article_df.index,
    columns=customer_article_df.columns,
)

# %% [markdown]
# ## Create a simple recommendation function
#
# Used the prediction dataframe from above
#
# This function recommends items that the user have not bought, but only users from the filtered 1000 users can only be recommended and only the items these users bought will only in the recommendation list

# %%
def print_item_info(item_no, detail_output=False):
    columns_to_print = [
        "prod_name",
        "product_type_name",
        "graphical_appearance_name",
        "colour_group_name",
        "section_name",
        "detail_desc",
    ]

    item_info = articles.loc[
        articles["article_id"].eq(item_no), columns_to_print
    ].squeeze()

    if detail_output:
        print(
            f'- "{item_info["prod_name"]}" which is a "{item_info["product_type_name"]}" with a color pattern of "{item_info["graphical_appearance_name"]} {item_info["colour_group_name"]}", it is a "{item_info["section_name"]}" and a detail description is "{item_info["detail_desc"]}"'
        )
    else:
        print(
            f'- {item_info["prod_name"]} : {item_info["graphical_appearance_name"]} {item_info["colour_group_name"]} {item_info["product_type_name"]}'
        )


def recommend_item_to_user(customer_id, detail_output=False):
    assert (
        customer_id in predicted_user_trans_df.index
    ), "Customer id not in prediction DataFrame."

    bought_items = transaction[transaction["customer_id"].eq(customer_id)][
        "article_id"
    ].unique()

    print("<Bought products info>")
    for item in bought_items:
        print_item_info(item, detail_output)

    predicted = predicted_user_trans_df.loc[customer_id]
    # filter out items which the user have not bought
    # order by the larges score and filter top 10
    top10_items = predicted[~predicted.index.isin(bought_items)].sort_values(
        ascending=False
    ).head(10)

    if len(top10_items) == 0:
        print("There is no items to recommend")
        return
    
    print("\n\n<Recommended Items>")
    for item in top10_items.index:
        print_item_info(item, detail_output)

# %% [markdown]
# ## Check function

# %%
recommend_item_to_user(random.choice(predicted_user_trans_df.index))
# Out:
# <Bought products info>
# - Luna skinny RW : Denim Blue Trousers
# - ED Madison Skinny HW : Solid Black Trousers
# - Luna skinny RW : Solid Black Trousers
# - Super soft : Denim Blue Trousers
# - Luna skinny RW : Denim Blue Trousers
# - Ocean : Solid Black Dress
# - W YODA KNIT OL OFFER : Melange Grey Sweater
# - Olivia dress : Melange Light Grey Sweater
# - Hanna : Solid White Sweater
# - Ocean : Solid Dark Green Dress
# - Luna skinny RW : Denim Blue Trousers
# - Mister Button : Solid Black Trousers
# - Curvy Jeggings HW Ankle : Solid Black Trousers
# - Skinny RW trouser. : Solid Black Trousers
# - Superstretch Fancy denim : Treatment Black Trousers
# - Stefan Scarf : Melange Black Scarf
# - Silver lake : Other structure Dark Beige Sweater
# - Olivier Knitted Scarf : Melange Dark Grey Scarf
# - Kaj Cable Scarf : Melange Black Scarf
# - Annette : Contrast Blue Sweater
# - Scarf Wolf : Solid Black Scarf
# - Jupiter v-neck : Melange Light Grey Sweater
# - Pete Plisse : Solid Black Dress
# - Skinny H.W Air : Denim Black Trousers
# - Tilly (1) : Solid White T-shirt
# - Tilly (1) : Solid Black T-shirt
# - Dottie : Solid White Blouse
# - Matey : Solid Red Sweater
# - Wendy : Solid Dark Blue Dress
# - Rachel : Melange Grey Sweater
# - Miranda : Melange Grey Sweater
# - Eve plisse skirt : All over pattern Light Beige Skirt
# - Neve Off Shoulder : Solid Black Sweater
# - ED Andrew : Jacquard Off White Sweater
# - Miranda : Melange Black Sweater
# - Elio jumpsuit : Lace Black Jumpsuit/Playsuit
# - Queen Sweater : Solid Black Sweater
# - Queen Sweater : Solid Yellow Sweater
# - Queen Sweater : Solid Light Orange Sweater
# - Kiruna Polo Neck : Solid Black Sweater
# - Queen Sweater : Dot Grey Sweater
# - Queen Sweater : Solid Dark Pink Sweater
# - Gatsby jumpsuit : Solid Black Trousers
# - Abi sneaker : Solid Black Sneakers
# - Sesam sneaker : Solid Black Sneakers
# - Viola Boot : Solid Black Boots
# - Pelargonia sneakerboot : Solid Black Sneakers
# - Svenne sneaker : Solid Black Sneakers
# - Morissette : Stripe Dark Blue T-shirt
# - Bootcut R.W : Denim White Trousers
# - Lima ss : Solid White T-shirt
# - Straight H.W : Denim Light Blue Trousers
# - Straight R.W : Denim White Trousers
# - Bella Bow choker : Solid Black Necklace
# - Skinny H.W : Denim Blue Trousers
# - Meela Skirt : Solid Dark Turquoise Skirt
# - Lizzie. : Stripe White T-shirt
# - Shaping Skinny H.W : Denim Dark Blue Trousers
# - Meela Skirt : Solid Black Skirt
# - Bobby : All over pattern Black Skirt
# - Linni tee (1) : Solid Off White T-shirt
# - Frille : Solid White Top
# - claudine : Solid Black T-shirt
# - 2- PACK : Solid White T-shirt
# - Linni tee : Placement print White T-shirt
# - Luisa tee : Front print White T-shirt
# - Tilly (1) : All over pattern Black T-shirt
# - Doris L/S : Stripe Black Top
# - Luisa tee : Stripe Grey T-shirt
# - Luna tee birds : Embroidery Dark Grey T-shirt
# - Embr front frill : Solid Light Yellow Top
# - Boulevard TOP PRODUCT : Embroidery White T-shirt
# - Billie. : Stripe Dark Blue T-shirt
# - Nord tee : Stripe Dark Blue Top
# - Terrier tee TOP PRODUCT : Placement print Black T-shirt
# - Franco tee : Solid Dark Blue Top
# - Luisa tee : Stripe Dark Blue T-shirt
# - ROBIE ISW 19 : Front print White T-shirt
# - ED Vincent top : All over pattern Off White Top
# - Cat Tee : Solid White T-shirt
# - ED Johnny top : Solid White Top
# - Irma SL-set print (J) : All over pattern Light Orange Pyjama set
# - HAMILTON : Front print Light Grey T-shirt
# - & Denim Boyfriend LW denim : Denim Light Blue Trousers
# - BYN Chiba dress : Lace Light Blue Dress
# - Elvissa shape swimsuit BIG : All over pattern Other Red Swimsuit
# - Timo Hoodie (K) : Application/3D Light Yellow Bra
# - & Denim Boyfriend LW denim : Denim Light Blue Trousers
# - Long shorts : Denim Blue Shorts
# - Linni tee : Placement print Dark Blue T-shirt
# - Pineapple swimsuit BIG : Solid Black Swimsuit
# - Eva : Solid Off White Sweater
# - Mineko top : Solid Off White T-shirt
# - Dixie tee : Stripe Red T-shirt
# - PC CS Flirty. : Jacquard Black Dress
# - ED Samantha slip skirt : All over pattern Beige Skirt
# - Kia Paperbag : Solid Dark Red Trousers
# - Bones paperbag waist HW : Solid Greenish Khaki Trousers
# - Sonja sweater dress : Solid Light Orange Dress
# - Felicia Plisse Scarf : Solid White Scarf
# - Jessie Scarf : Stripe Blue Scarf
# - ED Space jegging : Solid Black Trousers
# - Kanta trouser : Solid Black Trousers
# - Skinny RW denim : Denim Black Trousers
# - LOGG Solange RW : Solid Black Trousers
# - BRUCE CREW : Colour blocking Red Sweater
# - Mulder hood : Solid Grey Sweater
# - SHANE HOOD : Front print Dark Blue Hoodie
# - MAX DEAL HOOD : All over pattern Red Top
# - FRANKLIN HOOD : Stripe Off White Hoodie
# - Jannike plisse : Solid Off White Scarf
# - claudine : Solid White T-shirt
# - Saint Tropez : Solid White Blouse
# - TEAL T-SHIRT PRICE DRESS : Melange Grey Dress
# - TEAL T-SHIRT PRICE DRESS : Stripe Greenish Khaki Dress
# - TRUFFEL SKIRT : Solid Greenish Khaki Skirt
# - Mom HW Ankle Consc : Denim Light Blue Trousers
# - CLEMENTINE SKIRT : Solid Black Skirt
# - TEAL T-SHIRT PRICE DRESS : Stripe Dark Beige Dress
# - Nala : Solid White T-shirt
# - Lima SS. : Solid White T-shirt
# - TEAL T-SHIRT PRICE DRESS : Solid Black Dress
# - Brody V-neck : Solid Black T-shirt
# - claudine : Solid White T-shirt
# - Waleo HW wide full : All over pattern Black Trousers
# - Waleo HW wide full : All over pattern Black Trousers
# - Kimmy Sandal : Solid Black Sandals
# - Waleo HW wide full : All over pattern Yellow Trousers
# - Mara scallop : Solid Black Sandals
# - Waleo HW wide full : Solid Black Trousers
# - Roy Shorts : Solid Beige Shorts
# - Roy Shorts : Solid Dark Blue Shorts
# - Roy Shorts : Solid Dark Red Shorts
# - MARTINI TEE : Front print Dark Grey T-shirt
# - Kennedy skinny stretch chinos : Solid Black Trousers
# - NASA tee : Placement print White T-shirt
# - V-NECK SS SLIM 3 PK : Melange Dark Grey T-shirt
# - Kennedy skinny chinos : Solid Dark Green Trousers
# - MARTINI TEE : Front print Grey T-shirt
# - Buckle Up Triangle Top : Solid Black Bikini top
# - + Coco Highwaist : Solid Black Swimwear bottom
# - Class Cobra hoop pk : Solid Silver Earring
# - Julia RW Skinny Denim TRS : Solid Black Trousers
# - Jafar : Melange Light Beige Sweater
# - Jade HW Skinny Denim TRS : Solid Black Trousers
# - Madison skinny HW : Solid Black Trousers
# - Polo ss Nelly : Solid Dark Red Polo shirt
# - J Ballet : Solid Black Dress
# - Shiny becca : Solid Black Skirt
# - Liza Padded (Idro) 2pk : Solid Black Bra
# - Kelly Push (Melbourne) ctn 2p : Solid Light Beige Bra
# - Rae Push (Melbourne) 2p : Solid Black Bra
# - Kelly Lace Padded Idro 2p : Solid Light Beige Bra
# - Charlotte Push Melbourne : Solid Black Bra
# - Olivia push 2p : Solid Black Bra
# - Holly Push Melbourne : Solid Black Bra
# - Evie push 2p : Solid Black Bra
# - Fissa set bra + bottom : Lace Black Bra
# - Noah cowl neck dress : Melange Grey Top
# - Lily padded 2p : Contrast Light Grey Bra
# - Casper c&s push : Solid Black Bra
# - Moss Viscose Shirt : All over pattern Black Shirt
# - TD AOP photoflower : All over pattern Black Shirt
# - FF Iris leggings : Solid Black Leggings/Tights
# - TD Paisley GOW : All over pattern Black Shirt
# - Moss Viscose Shirt : All over pattern Dark Red Shirt
# - H2 Flores skirt : Sequin Light Beige Skirt
# - PC Flores : Sequin Dark Green Skirt
# - PC Sparkle J TU : Glittering/Metallic Black Skirt
# - Billie high 2-pack : Solid Black T-shirt
# - Waif Wide leg trouser RW : Stripe Dark Blue Trousers
# - DIV Norma trouser : All over pattern Black Trousers
# - Tess : Stripe Light Beige Dress
# - CAMILLA OL OFFER : Solid White Sweater
# - Swift Dress(1) : Solid Dark Green Dress
# - ED Mirella dress : Solid Black Dress
# - Swift Dress(1) : All over pattern Beige Dress
# - MC Swift dress : Solid Dark Green Dress
# - Audrina dress : Solid Black Dress
# - KISSY DRESS : Stripe Dark Blue Dress
# - KISSY DRESS : Melange Grey Dress
# - Shelley : Check Black Skirt
# - Starlight : Solid Black Dress
# - PC Waterfall : Solid Off White Dress
# - Bangles Cardigan : Melange Grey Cardigan
# - Maltese trow on cardigan : Melange Light Grey Cardigan
# - Calgary Cardigan : Melange Grey Cardigan
# - Siri Cardigan : Melange Light Grey Cardigan
# - Canada Cardigan : Solid Beige Cardigan
# - Maja Cardigan TVP : Melange Light Grey Cardigan
# - Barry cardigan : Melange Light Grey Cardigan
# - Scarlet cable cardigan : Melange Grey Cardigan
# - Michelle Zip : Solid Blue Trousers
# - Lydon cardigan hood grey : Solid Grey Hoodie
# - Soller RW wide cropped : Stripe Black Trousers
# - Daiquiri Pull- On TRS : Solid Light Pink Trousers
# - Daiquiri Pull- On TRS : Solid Greenish Khaki Trousers
# - Beach straight dressed trs : Check Grey Trousers
# - Foxtail wide pant : All over pattern Light Green Trousers
# - Lydon cardigan hood grey : Solid Light Pink Hoodie
# - Becky softpant : Solid Black Trousers
# - Spring trousers : Stripe Off White Trousers
# - Manchester dress : Solid Black Dress
# - ED Becky trouser : Solid Greenish Khaki Trousers
# - Cool Fridolf Necklace : Solid Silver Necklace
# - Juan : Solid Light Beige Vest top
# - Jen tee : Placement print White T-shirt
# - Flirty Cornwall Necklace : Solid Silver Necklace
# - Margarita RW Pull- On Shorts : Solid Black Shorts
# - Epic Padded Swimsuit : All over pattern Black Swimsuit
# - Juan : All over pattern Black Vest top
# - Lyra HW wide full(1) : Solid Black Trousers
# - ED Becky trouser : All over pattern Light Beige Trousers
# - Pez trouser : All over pattern Black Trousers
# - ED Becky trouser : All over pattern Black Trousers
# - Sandy trousers : Solid Black Trousers
# - Pez trouser : All over pattern Light Beige Trousers
# - Sandy trousers : Solid Grey Trousers
# - Montjoy Trousers : All over pattern Off White Trousers
# - Ibiza HW Woven Pull-on : Solid Black Trousers
# - Ibiza HW Woven Pull-on : Dot Black Trousers
# - Lyra HW wide full : All over pattern Light Beige Trousers
# - Ibiza HW Woven Pull-on : All over pattern Black Trousers
# - Montjoy Trousers : All over pattern Black Trousers
# - Vacation HW wide cropped : Stripe Light Beige Trousers
# - DIV Mont Joy trs : All over pattern Black Trousers
# - Brody trs : Solid Black Trousers
# - Palma Trousers : All over pattern Light Beige Trousers
# - Palma Trousers : Solid Black Trousers
# - &DENIM Jeggings HW : Solid Black Trousers
# - &DENIM+ Skinny shaping RW : Denim Black Trousers
# - Scary Spice Swimsuit : Solid Black Swimsuit
# - Take a Hike Unpad Swimsuit : Solid Black Swimsuit
# - Walkover Unpadded Swimsuit : Solid Black Swimsuit
# - Mom Fit Ultra HW : Denim Blue Trousers
# - ED Nora tee 2p : Solid Black T-shirt
# - DIV Fancy pants : All over pattern Light Purple Trousers
# - Perrie Slim Mom Denim TRS : Solid Light Blue Trousers
# - Amalfi Blouse RTW : Solid White Blouse
# - Honey Shape Swimsuit : All over pattern Black Swimsuit
# - Spanx Alot Shape Swimsuit NEW : All over pattern Dark Blue Swimsuit
# - &DENIM+ Mom fit HW : Denim Blue Trousers
# - COZY DORRI TOP : Solid White Sweater
# - Poca Coat : Solid Greenish Khaki Coat
# - ED Madison Skinny HW : Denim Dark Grey Trousers
# - DIV+ Victorville pull on : Solid Black Trousers
# - &DENIM+ Skinny Shaping HW : Denim Black Trousers
# - Freddy Skirt : Jacquard Black Skirt
# - ED Space Jeggings : Solid Black Trousers
# - Queen Sweater : Embroidery White Sweater
# - Mona : Solid Yellow Top
# - Winnie top : Solid Off White Sweater
# - Tara turtleneck top : Solid Off White Sweater
# - Fred hood : Embroidery Red Hoodie
# - NEW LOGG DeLuca pull on : Solid Black Trousers
# - &DENIM+ Girlfriend RW : Denim Dark Blue Trousers
# - ED Space Jeggings : Denim Dark Blue Trousers
# - Flamingo : Solid Dark Green Coat
# - Cinderella : Melange Light Grey Sweater
# - DIV+ Sunset Pull on : Solid Greenish Khaki Trousers
# - Mona : Solid White Top
# - Bob v-neck 2-pack : Melange Dark Grey T-shirt
# - Alexia top : Solid White Top
# - Billie high 2p. : Solid Black T-shirt
# - Hazel : Solid Black T-shirt
# - Brody : Solid White T-shirt
# - Cat cotton tee : Solid White T-shirt
# - Tara turtleneck top : Solid Black Sweater
# - Brittany LS : Solid White Top
# - Billie high 2p. : Melange Light Beige T-shirt
# - Curvy Jegging HW. : Denim Black Trousers
#
#
# <Recommended Items>
# - Rebecca or Delphine shirt : Solid Black Shirt
# - BB First layer set : Solid Black Garment Set
# - Super Skinny L.W Epic : Solid Black Trousers
# - Ellen Push (Melbourne) 2p : Solid Dark Grey Bra
# - Julia Denim Petite Trs 1 : Solid Black Trousers
# - Kanta slacks RW : Solid Black Trousers
# - Luna skinny RW : Solid White Trousers
# - Skinny R.W Chic : Denim Dark Blue Trousers
# - Alexia blouse : Solid White Blouse
# - Samantha Padded T-shirt Milano : Solid White Bra
